# %%
#import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import os
from pprint import pprint
import requests
import json
import html
from scipy.stats import linregress
import statsmodels.api as sm
import seaborn as sns

# %%
csv_merge = "../Resources/merged2014.csv"
df_2014 = pd.read_csv(csv_merge)
df_2014.head()
# Out:
#    Unnamed: 0  Year                 Region ISO2 ISO3  ODB-Rank      Country  \
# 0           2  2014  Europe & Central Asia   SE  SWE         3       Sweden
# 1           3  2014  Europe & Central Asia   FR  FRA         4       France
# 2           4  2014    East Asia & Pacific   NZ  NZL         4  New Zealand
# 3           5  2014  Europe & Central Asia   NL  NLD         6  Netherlands
# 4           6  2014  Europe & Central Asia   NO  NOR         7       Norway
#
#    ODB-Score-Scaled  Readiness-Scaled  Implementation-Innovation-Scaled  ...  \
# 0             83.70               100                                67  ...
# 1             80.21                91                                75  ...
# 2             80.01                81                                76  ...
# 3             75.79                95                                79  ...
# 4             74.59                88                                70  ...
#
# ...

# %%
csv_merge = "../Resources/merged2016.csv"
df_2016 = pd.read_csv(csv_merge)
df_2016.head()
# Out:
#    Year                 Region ISO2 ISO3  ODB-Rank                   Country  \
# 0  2016          North America   CA  CAN         2                    Canada
# 1  2016  Europe & Central Asia   FR  FRA         3                    France
# 2  2016          North America   US  USA         4  United States of America
# 3  2016    East Asia & Pacific   AU  AUS         5                 Australia
# 4  2016    East Asia & Pacific   NZ  NZL         7               New Zealand
#
#    ODB-Score-Scaled  Readiness-Scaled  Implementation-Innovation-Scaled  \
# 0             89.54                96                                87
# 1             85.13               100                                77
# 2             81.62                96                                84
# 3             81.15                85                                79
# 4             79.38                92                                53
#
#    Implementation-Social-Scaled  ...  Impact-Political-Scaled  \
# ...

# %%
# alternatively you can set your suffixes when the merge occurs
df_merge_1416 = pd.merge(
    df_2014, df_2016, on="Country", suffixes=("_2014", "_2016"), how = "outer")
df_merge_1416.head()
# Out:
#    Unnamed: 0  Year_2014            Region_2014 ISO2_2014 ISO3_2014  \
# 0         2.0     2014.0  Europe & Central Asia        SE       SWE
# 1         3.0     2014.0  Europe & Central Asia        FR       FRA
# 2         4.0     2014.0    East Asia & Pacific        NZ       NZL
# 3         5.0     2014.0  Europe & Central Asia        NL       NLD
# 4         6.0     2014.0  Europe & Central Asia        NO       NOR
#
#    ODB-Rank_2014      Country  ODB-Score-Scaled_2014  Readiness-Scaled_2014  \
# 0            3.0       Sweden                  83.70                  100.0
# 1            4.0       France                  80.21                   91.0
# 2            4.0  New Zealand                  80.01                   81.0
# 3            6.0  Netherlands                  75.79                   95.0
# 4            7.0       Norway                  74.59                   88.0
#
#    Implementation-Innovation-Scaled_2014  ...  Impact-Political-Scaled_2016  \
# ...

# %%
df_merge_1416.to_csv("newmerge_1416.csv")

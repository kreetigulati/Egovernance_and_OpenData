# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
import requests
import json
import codecs
import gmaps
from api_keys import g_key
from pprint import pprint
import seaborn as sns
import statsmodels.api as sm

# %%
df = pd.read_csv("joined1416.csv")

# %%
df.drop(columns = "Unnamed: 0")
# Out:
#      Year                      Region ISO2 ISO3  ODB-Rank      Country  \
# 0    2014       Europe & Central Asia   SE  SWE         3       Sweden
# 1    2014       Europe & Central Asia   FR  FRA         4       France
# 2    2014         East Asia & Pacific   NZ  NZL         4  New Zealand
# 3    2014       Europe & Central Asia   NL  NLD         6  Netherlands
# 4    2014       Europe & Central Asia   NO  NOR         7       Norway
# ..    ...                         ...  ...  ...       ...          ...
# 176  2016          Sub-Saharan Africa   MZ  MOZ       110   Mozambique
# 177  2016          Sub-Saharan Africa   ML  MLI       111         Mali
# 178  2016          Sub-Saharan Africa   ZW  ZWE       111     Zimbabwe
# 179  2016         East Asia & Pacific   MM  MMR       113      Myanmar
# 180  2016  Middle East & North Africa   YE  YEM       114        Yemen
#
#      ODB-Score-Scaled  Readiness-Scaled  Implementation-Innovation-Scaled  \
# ...

# %%
country = df.loc[df["Year"]==2014]["Country"]
tt14 = df.loc[df["Year"]==2014]["ODB-Score-Scaled"]
tt16 = df.loc[df["Year"]==2016]["ODB-Score-Scaled"]
reg = df.loc[df["Year"]==2014]["Region"]

testdata = pd.DataFrame({"Countries": country,
                        "ODB 14": tt14,
                        "ODB 16": tt16,
                        "Region": reg})
testdata
# Out:
#        Countries  ODB 14  ODB 16                 Region
# 0         Sweden   83.70     NaN  Europe & Central Asia
# 1         France   80.21     NaN  Europe & Central Asia
# 2    New Zealand   80.01     NaN    East Asia & Pacific
# 3    Netherlands   75.79     NaN  Europe & Central Asia
# 4         Norway   74.59     NaN  Europe & Central Asia
# ..           ...     ...     ...                    ...
# 176          NaN     NaN    3.46                    NaN
# 177          NaN     NaN    2.46                    NaN
# 178          NaN     NaN    1.87                    NaN
# 179          NaN     NaN    1.33                    NaN
# 180          NaN     NaN    0.00                    NaN
#
# [181 rows x 4 columns]

# %%
tt16.reset_index()
# Out:
#      index  ODB-Score-Scaled
# 0       79             89.54
# 1       80             85.13
# 2       81             81.62
# 3       82             81.15
# 4       83             79.38
# ..     ...               ...
# 97     176              3.46
# 98     177              2.46
# 99     178              1.87
# 100    179              1.33
# 101    180              0.00
#
# [102 rows x 2 columns]

# %%
x1 = df.loc[df["Year"]==2014]["Readiness-Scaled"]
y1 = df.loc[df["Year"]==2014]["ODB-Score-Scaled"]
x2 = df.loc[df["Year"]==2016]["Readiness-Scaled"]
y2 = df.loc[df["Year"]==2016]["ODB-Score-Scaled"]

results1 = sm.OLS(y1,sm.add_constant(x1)).fit()

print(results1.summary())

results2 = sm.OLS(y2,sm.add_constant(x2)).fit()

print(results2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       ODB-Score-Scaled   R-squared:                       0.893
# Model:                            OLS   Adj. R-squared:                  0.891
# Method:                 Least Squares   F-statistic:                     640.5
# Date:                Wed, 19 May 2021   Prob (F-statistic):           4.60e-39
# Time:                        21:12:53   Log-Likelihood:                -269.26
# No. Observations:                  79   AIC:                             542.5
# Df Residuals:                      77   BIC:                             547.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -8.6729      1.864     -4.653      0.000     -12.385      -4.961
# ...

# %%
x1 = df.loc[df["Year"]==2014]["Implementation-Social-Scaled"]
y1 = df.loc[df["Year"]==2014]["ODB-Score-Scaled"]
x2 = df.loc[df["Year"]==2016]["Implementation-Social-Scaled"]
y2 = df.loc[df["Year"]==2016]["ODB-Score-Scaled"]

results1 = sm.OLS(y1,sm.add_constant(x1)).fit()

print(results1.summary())

results2 = sm.OLS(y2,sm.add_constant(x2)).fit()

print(results2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       ODB-Score-Scaled   R-squared:                       0.738
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     216.8
# Date:                Wed, 19 May 2021   Prob (F-statistic):           4.29e-24
# Time:                        21:13:32   Log-Likelihood:                -304.53
# No. Observations:                  79   AIC:                             613.1
# Df Residuals:                      77   BIC:                             617.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                           -0.6862      2.664     -0.258      0.797      -5.990       4.618
# ...

# %%
x1 = df.loc[df["Year"]==2014]["Impact-Social-Scaled"]
y1 = df.loc[df["Year"]==2014]["ODB-Score-Scaled"]
x2 = df.loc[df["Year"]==2016]["Impact-Social-Scaled"]
y2 = df.loc[df["Year"]==2016]["ODB-Score-Scaled"]

results1 = sm.OLS(y1,sm.add_constant(x1)).fit()

print(results1.summary())

results2 = sm.OLS(y2,sm.add_constant(x2)).fit()

print(results2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       ODB-Score-Scaled   R-squared:                       0.470
# Model:                            OLS   Adj. R-squared:                  0.464
# Method:                 Least Squares   F-statistic:                     68.39
# Date:                Wed, 19 May 2021   Prob (F-statistic):           3.07e-12
# Time:                        21:14:04   Log-Likelihood:                -332.31
# No. Observations:                  79   AIC:                             668.6
# Df Residuals:                      77   BIC:                             673.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   24.5726      2.144     11.459      0.000      20.303      28.843
# ...

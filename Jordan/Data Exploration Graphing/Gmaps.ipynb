# %%
import gmaps
from config import (api_key)
import gmaps
gmaps.configure(api_key=api_key)
import pandas as pd
import requests
import json

# %%
csv_merge = "../Resources/newmerge_1416.csv"
df_1416= pd.read_csv(csv_merge)
df_1416.head()
# Out:
#              Region_2014 ISO  ODB-Rank_2014      Country  \
# 0  Europe & Central Asia  SE              3       Sweden
# 1  Europe & Central Asia  FR              4       France
# 2    East Asia & Pacific  NZ              4  New Zealand
# 3  Europe & Central Asia  NL              6  Netherlands
# 4  Europe & Central Asia  NO              7       Norway
#
#    ODB-Score-Scaled_2014  Readiness-Scaled_2014  \
# 0                  83.70                    100
# 1                  80.21                     91
# 2                  80.01                     81
# 3                  75.79                     95
# 4                  74.59                     88
#
#    Implementation-Innovation-Scaled_2014  Implementation-Social-Scaled_2014  \
# 0                                     67                                 81
# 1                                     75                                 79
# 2                                     76                                 83
# ...

# %%
fig = gmaps.figure()
geojson = gmaps.geojson_layer(df_1416['Country'])
fig.add_layer(geojson)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-141abf188973> in <module>
#       1 fig = gmaps.figure()
# ----> 2 geojson = gmaps.geojson_layer(df_1416['Country'])
#       3 fig.add_layer(geojson)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gmaps/geojson_layer.py in geojson_layer(geojson, fill_color, fill_opacity, stroke_color, stroke_opacity, stroke_weight)
#     220         A :class:`gmaps.GeoJson` instance.
#     221     """
# --> 222     _validate_geojson(geojson)
#     223     styled_geojson = copy.deepcopy(geojson)
#     224     raw_features = styled_geojson["features"]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gmaps/geojson_layer.py in _validate_geojson(geojson_document)
#     112 def _validate_geojson(geojson_document):
#     113     try:
# --> 114         geojson_instance = geojson.loads(json.dumps(geojson_document))
# ...

# %%
countries_string = requests.get("https://raw.githubusercontent.com/johan/world.geo.json/master/countries.geo.json"
).content
countries = json.loads(countries_string)

# %%
df_1416['Coordinates'] = ""

# %%
country_dict = ""
for country in df_1416:
    countries_string = requests.get("https://raw.githubusercontent.com/johan/world.geo.json/master/countries.geo.json")
    if countries['features'][0]['properties']['name'] == df_1416['Country']:
        countries['features'][0]['geometry']['coordinates'].append(country_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-1ca18b9ec452> in <module>
#       2 for country in df_1416:
#       3     countries_string = requests.get("https://raw.githubusercontent.com/johan/world.geo.json/master/countries.geo.json")
# ----> 4     if countries['features'][0]['properties']['name'] == df_1416['Country']:
#       5         countries['features'][0]['geometry']['coordinates'].append(country_dict)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
response_json['features'][1]['geometry']['coordinates']
# Out:
# [[[[16.326528, -5.87747],
#    [16.57318, -6.622645],
#    [16.860191, -7.222298],
#    [17.089996, -7.545689],
#    [17.47297, -8.068551],
#    [18.134222, -7.987678],
#    [18.464176, -7.847014],
#    [19.016752, -7.988246],
#    [19.166613, -7.738184],
#    [19.417502, -7.155429],
#    [20.037723, -7.116361],
#    [20.091622, -6.94309],
#    [20.601823, -6.939318],
#    [20.514748, -7.299606],
#    [21.728111, -7.290872],
#    [21.746456, -7.920085],
#    [21.949131, -8.305901],
#    [21.801801, -8.908707],
#    [21.875182, -9.523708],
#    [22.208753, -9.894796],
#    [22.155268, -11.084801],
#    [22.402798, -10.993075],
#    [22.837345, -11.017622],
#    [23.456791, -10.867863],
#    [23.912215, -10.926826],
#    [24.017894, -11.237298],
#    [23.904154, -11.722282],
#    [24.079905, -12.191297],
#    [23.930922, -12.565848],
#    [24.016137, -12.911046],
#    [21.933886, -12.898437],
#    [21.887843, -16.08031],
#    [22.562478, -16.898451],
#    [23.215048, -17.523116],
# ...

# %%
country_name = countries['features'][0]['properties']['name']
country = df_1416['Country']

df_1416['Coordinates'] = ""
#country_dict = {}

for name in country:
    response = requests.get("https://raw.githubusercontent.com/johan/world.geo.json/master/countries.geo.json")
    response_json = response.json()
    if df_1416['Country'] == countries['features'][0]['properties']['name']:
#         country_dict['country'] = countries['features'][0]['properties']['name']
#         country_dict['polygon'] = 
        countries['features'][0]['geometry'].append(df_1416['Coordinates'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-6fff021d4ee8> in <module>
#       8     response = requests.get("https://raw.githubusercontent.com/johan/world.geo.json/master/countries.geo.json")
#       9     response_json = response.json()
# ---> 10     if df_1416['Country'] == countries['features'][0]['properties']['name']:
#      11 #         country_dict['country'] = countries['features'][0]['properties']['name']
#      12 #         country_dict['polygon'] =
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ...

# %%
#country_name = countries['features'][0]['properties']['name']
country = df_1416['Country']

df_1416['Coordinates'] = ""


for name in country:
    response = requests.get("https://raw.githubusercontent.com/johan/world.geo.json/master/countries.geo.json")
    response_json = response.json()
    country_dict = {}
    country_dict['country'] = countries['features']['properties']['name']
    country_dict['polygon'] = countries['features']['geometry']['coordinates']
#        countries['features'][0]['geometry'].append(df_1416['Coordinates'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-8283aa461991> in <module>
#       9
#      10         country_dict = {}
# ---> 11         country_dict['country'] = countries['features']['properties']['name']
#      12         country_dict['polygon'] = countries['features']['geometry']['coordinates']
#      13 #        countries['features'][0]['geometry'].append(df_1416['Coordinates'])
#
# TypeError: list indices must be integers or slices, not str

# %%
response_json['features']['properties']['name']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-a8587bfafd19> in <module>
# ----> 1 response_json['features']['properties']['name']
#
# TypeError: list indices must be integers or slices, not str

# %%
country = df_1416['Country']

#df_1416['Coordinates'] = ""


for name in country:
    response = requests.get("https://raw.githubusercontent.com/johan/world.geo.json/master/countries.geo.json")
    response_json = response.json()
    country_dict = {}
    country_dict['country'] = response_json['features']['properties']['name']
    country_dict['polygon'] = response_json['features']['geometry']['coordinates']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-77c380f68234> in <module>
#       8     response_json = response.json()
#       9     country_dict = {}
# ---> 10     country_dict['country'] = response_json['features']['properties']['name']
#      11     country_dict['polygon'] = response_json['features']['geometry']['coordinates']
#
# TypeError: list indices must be integers or slices, not str

# %%
df = pd.DataFrame(df_1416['Country'])

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-95d830806c10> in <module>
# ----> 1 df['Coordinates'] = df['Country'].map(response_json['features'][0]['geometry']['coordinates'])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3968         dtype: object
#    3969         """
# -> 3970         new_values = super()._map_values(arg, na_action=na_action)
#    3971         return self._constructor(new_values, index=self.index).__finalize__(
#    3972             self, method="map"
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1158
#    1159         # mapper is a function
# -> 1160         new_values = map_f(values, mapper)
#    1161
#    1162         return new_values
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ...

# %%
df
# Out:
#         Country Coordinates
# 0        Sweden         NaN
# 1        France         NaN
# 2   New Zealand         NaN
# 3   Netherlands         NaN
# 4        Norway         NaN
# ..          ...         ...
# 74        Yemen         NaN
# 75     Cameroon         NaN
# 76         Mali         NaN
# 77        Haiti         NaN
# 78      Myanmar         NaN
#
# [79 rows x 2 columns]

# %%
countries_string = requests.get(
    "https://raw.githubusercontent.com/johan/world.geo.json/master/countries.geo.json").content
countries = json.loads(countries_string)
fig = gmaps.figure()
geojson = gmaps.geojson_layer(countries)
fig.add_layer(geojson)

import random
colors = [random.choice(['red', 'green', 'blue', 'purple', 'yellow', 'teal'])
    for country in countries['features']
    geojson = gmaps.geojson_layer(countries, fill_color=colors, fill_opacity=0.2, stroke_weight=1)
fig
# Out:
#   File "<ipython-input-97-99f03ecd9973>", line 11
#     geojson = gmaps.geojson_layer(countries, fill_color=colors, fill_opacity=0.2, stroke_weight=1)
#     ^
# SyntaxError: invalid syntax
